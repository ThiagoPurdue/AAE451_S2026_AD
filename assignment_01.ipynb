# %% [markdown]
# <a href="https://colab.research.google.com/github/ThiagoPurdue/AAE451_S2026_AD/blob/main/assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AAE 451 – Aircraft Design
#
# ### Assignment 1: Baseline Characterization and Gap Analysis
#
# **Reference:** 2025-2026 Undergraduate Team Aircraft Design RFP

# %% [markdown]
# #### 1. Overview
#
# The Request for Proposal (RFP) identifies the **F/A-18E/F Super Hornet** as the baseline aircraft that your new design must replace and outperform. To design a superior aircraft, we must first quantify the performance, geometry, and limitations of the current baseline aircraft.
#
# Designing a replacement aircraft is an exercise in "gap analysis": determining exactly where the current fleet falls short of future requirements. This assignment will guide you through gathering historical and technical data to populate a **"Baseline Comparison Matrix"** which will serve as the reference matrix for your entire semester's project.

# %% [markdown]
# #### 2. Objectives
#
# * **Identify** key geometric and performance parameters of the F/A-18E/F Super Hornet.
#
# * **Verify** the accuracy of the reference data provided in the RFP (specifically the carrier suitability tables).
#
# * **Determine** the "Performance Gaps" between the current fleet capability and the new RFP requirements.
#
# * **Establish** the geometric constraints (spot factor, deck handling) that will drive your initial sizing.

# %% [markdown]
# #### 3. Required Tasks
#
# ##### Task A: The Data Verification Audit (CRITICAL)
#
# **Context:** The RFP provides a "Catalog of Current Carrier Suitability Data" in **Section 5, Table 3.1.10-II** (Page 8). This table lists an entry for "F/A-18".
#
# **Your Task:**
#
# 1. Locate independent, reliable sources for the **F/A-18E/F Super Hornet** (use the links provided in the RFP or official Navy Fact Files).
#
# 2. Compare the Length and Gross Weight in the RFP table against your independent sources.
#
# 3. **Determine:** Does the RFP table describe the *Super Hornet* (E/F models) or the *Legacy Hornet* (A/C models)?
#
# 4. **Action:** If the table is incorrect or outdated, you must derive the *correct* values for the Super Hornet to use in your Baseline Matrix. *Do not simply copy the RFP table data if it does not match the baseline aircraft.*
#
# #### Task B: Detailed Geometric Characterization
#
# You must move beyond basic dimensions and gather the detailed sizing data required to generate an initial OpenVSP or CAD model. Create and populate a **Detailed Geometry Table** with the following:
#
# * **Main Wing:**
#     * Reference Area ($S_{ref}$), Aspect Ratio ($AR$), Taper Ratio ($\lambda$).
#     * Sweep angles (Leading Edge $\Lambda_{LE}$ and Quarter-Chord $\Lambda_{c/4}$).
#     * Airfoil types (Root and Tip) or Thickness-to-Chord ratios ($t/c$).
#     * Incidence and Dihedral angles.
#
# * **Empennage (Tail Surfaces):**
#     * **Horizontal Stabilator:** Area, Span, Sweep, Taper Ratio, and Airfoil/Thickness.
#     * **Vertical Stabilizers:** Area (per tail), Height, Sweep, Taper Ratio, and Cant Angle (degrees from vertical).
#     * **Tail Arm:** Measure/Estimate the distance between the Main Wing Quarter-Chord ($c/4$) and the Horizontal Tail Quarter-Chord ($c/4$). This is critical for longitudinal stability calculations.
#
# * **Fuselage:**
#     * Total Length (compare specifically to the RFP 50 ft limit).
#     * Max Width and Max Height.
#     * **Cross-Section:** Characterize the fuselage cross-section shape (e.g., rectangular, blended) and estimated Fineness Ratio ($L/D_{equiv}$).
#
# * **Landing Gear:**
#     * **Type:** Confirm configuration (e.g., Tricycle).
#     * **Geometry:** Wheelbase (distance nose-to-main) and Track Width (distance main-to-main).
#     * **Tires:** Diameter and Width for both Main and Nose gear (Crucial for packaging).
#     * **Struts:** Estimated extended length.
#     * **Kinematics:** Verify the "Tip-Back Angle" (angle of rotation around main gear before tail strikes ground).
#
# #### Task C: Performance Gap Analysis
#
# Create and fill in a **Performance Matrix** to identify where the new design must improve.
#
# * **Range:** Compare the RFP's 700 nm combat radius requirement against the actual internal-fuel combat radius of the Super Hornet. *This is likely your primary design driver.*
#
# * **Speed:** Compare the desired Mach 2.0 dash speed against the Super Hornet's actual top speed.
#
# * **Approach:** Compare the required <145 kt approach speed against the baseline.

# %% [markdown]
# ### 4. Deliverables
#
# **1. Baseline Comparison Memo (PDF)**
#
# * **Format:** 1-2 pages, standard professional memo format.
#
# * **Content:**
#   * **Executive Summary:** Briefly state the most significant challenge you discovered (e.g., "The Super Hornet is X feet longer than the RFP allows...").
#   * **Data Audit Result:** Definitive statement on whether the RFP table data was for the Legacy or Super Hornet, and the corrected values you are using.
#   * **The "Gap":** A brief discussion of the largest performance gap (Range, Speed, or Payload) that will drive your design.
#   * **Attachments:** Attach the completed **Detailed Geometry Table** and **Performance Gap Table**.
#
# **2. Completed Data Tables (.csv or .xlsx)**
#
# * Submit the filled-out Geometry and Performance tables.

# %% [markdown]
# ### 5. Resources & References
#
# * **RFP Link 2:** *F/A-18E/F Super Hornet Aircraft (F/A-18E/F) SAR* (See Page 9 of RFP).
#
# * **RFP Link 3:** *Lessons Learned from the F/A-18E/F Development Programs*.
#
# * **Official Navy Fact File:** [Navy.mil F/A-18E/F Page](https://www.navy.mil/Resources/Fact-Files/Display-FactFiles/Article/2383479/fa-18a-d-hornet-and-fa-18ef-super-hornet-strike-fighter/)

# %% [markdown]
# ---

# %% [markdown]
# ### Appendix: Data Collection Templates
#
# Use the code block below to generate the data tables. You can fill them in programmatically or export them to Excel/CSV to fill in manually.

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# ==========================================
# DATA GENERATION
# ==========================================

def get_detailed_geometry_template():
    """Generates the Detailed Geometric Parameters Matrix"""
    data = [
        # (Component, Parameter, Unit, RFP Constraint, Baseline_Actual (Student to Fill), Source)
        ("Global", "Overall Length", "ft", "<= 50.0", "", ""),
        ("Global", "Wingspan (Unfolded)", "ft", "<= 60.0", "", ""),
        ("Global", "Wingspan (Folded)", "ft", "<= 35.0", "", ""),
        ("Global", "Max Takeoff Weight", "lb", "<= 90,000", "", ""),
        ("Fuselage", "Fineness Ratio (L/D)", "-", "N/A", "", ""),
        ("Fuselage", "Max Cross-Section Width", "ft", "N/A", "", ""),
        ("Fuselage", "Max Cross-Section Height", "ft", "N/A", "", ""),
        ("Main Wing", "Reference Area (S)", "ft^2", "N/A", "", ""),
        ("Main Wing", "Aspect Ratio (AR)", "-", "N/A", "", ""),
        ("Main Wing", "Sweep (Leading Edge)", "deg", "N/A", "", ""),
        ("Main Wing", "Sweep (Quarter Chord)", "deg", "N/A", "", ""),
        ("Main Wing", "Taper Ratio", "-", "N/A", "", ""),
        ("Main Wing", "Airfoil (Root / Tip)", "Type", "N/A", "", ""),
        ("Main Wing", "Dihedral", "deg", "N/A", "", ""),
        ("Horiz. Tail", "Area", "ft^2", "N/A", "", ""),
        ("Horiz. Tail", "Sweep (Leading Edge)", "deg", "N/A", "", ""),
        ("Horiz. Tail", "Taper Ratio", "-", "N/A", "", ""),
        ("Horiz. Tail", "Tail Arm (Wing c/4 to HT c/4)", "ft", "N/A", "", ""),
        ("Vert. Tail", "Area (per side)", "ft^2", "N/A", "", ""),
        ("Vert. Tail", "Height", "ft", "N/A", "", ""),
        ("Vert. Tail", "Cant Angle", "deg", "N/A", "", ""),
        ("Vert. Tail", "Taper Ratio", "-", "N/A", "", ""),
        ("Landing Gear", "Type", "-", "Tricycle", "", ""),
        ("Landing Gear", "Wheelbase", "ft", "N/A", "", ""),
        ("Landing Gear", "Track Width", "ft", "N/A", "", ""),
        ("Landing Gear", "Main Tire Size (Dia x Width)", "in", "N/A", "", ""),
        ("Landing Gear", "Nose Tire Size (Dia x Width)", "in", "N/A", "", ""),
        ("Landing Gear", "Tip-Back Angle", "deg", "> 15 (typ)", "", ""),
    ]
    return pd.DataFrame(data, columns=["Component", "Parameter", "Unit", "RFP Limit/Ref", "F/A-18E/F Baseline (Actual)", "Source"])

def get_performance_template():
    """Generates the Performance Metrics & Compliance Matrix"""
    data = [
        # (Mission Phase, Metric, Condition, RFP Requirement, Baseline_Actual (Student to Fill), Source)
        ("Launch", "Wind Over Deck (WOD)", "Tropical Day", "0 kts", "", ""),
        ("Launch", "Launch Endspeed", "Max Lift", "See C-13-2 Curves", "", ""),
        ("Cruise/Dash", "Max Speed (Vmax)", "30k ft", "Mach 1.6 (Req)", "", ""),
        ("Mission", "Combat Radius (Strike)", "Internal Fuel", ">= 700 nm", "", ""),
        ("Maneuver", "Sustained Turn Rate", "20k ft", ">= 8.0 deg/sec", "", ""),
        ("Maneuver", "Vertical Load Factor", "Mid Mission", ">= 7.0 g", "", ""),
        ("Recovery", "Approach Speed", "Landing Wt", "< 145 kts", "", ""),
        ("Recovery", "Arresting WOD", "Max", "<= 15 kts", "", ""),
        ("Recovery", "Single Engine ROC", "Approach", ">= 500 ft/min", "", ""),
    ]
    return pd.DataFrame(data, columns=["Mission Phase", "Metric", "Condition", "RFP Requirement", "F/A-18E/F Baseline (Actual)", "Source"])

# ==========================================
# DISPLAY & EXPORT
# ==========================================

# Generate the empty student tables
df_geo = get_detailed_geometry_template()
df_perf = get_performance_template()

# Display formatted tables
display(Markdown("### Table 1: Detailed Geometric Characterization"))
display(df_geo)
print("\n" + "="*80 + "\n")

display(Markdown("### Table 2: Performance Gap Analysis"))
display(df_perf)

# Optional: Uncomment to export
df_geo.to_csv('01_Geometry_Detailed.csv', index=False)
df_perf.to_csv('02_Performance_Gap.csv', index=False)
# Out:
# ### Table 1: Detailed Geometric Characterization
#        Component                      Parameter  Unit RFP Limit/Ref  \
# 0         Global                 Overall Length    ft       <= 50.0
# 1         Global            Wingspan (Unfolded)    ft       <= 60.0
# 2         Global              Wingspan (Folded)    ft       <= 35.0
# 3         Global             Max Takeoff Weight    lb     <= 90,000
# 4       Fuselage           Fineness Ratio (L/D)     -           N/A
# 5       Fuselage        Max Cross-Section Width    ft           N/A
# 6       Fuselage       Max Cross-Section Height    ft           N/A
# 7      Main Wing             Reference Area (S)  ft^2           N/A
# 8      Main Wing              Aspect Ratio (AR)     -           N/A
# 9      Main Wing           Sweep (Leading Edge)   deg           N/A
# 10     Main Wing          Sweep (Quarter Chord)   deg           N/A
# 11     Main Wing                    Taper Ratio     -           N/A
# ...
